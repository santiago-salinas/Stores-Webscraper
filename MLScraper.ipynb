# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://listado.mercadolibre.com.uy/vinilo-pizarra#D[A:vinilo%20pizarra,L:undefined]"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Find all span elements with the specific class
spans = soup.find_all("span", class_="andes-money-amount__fraction", attrs={"aria-hidden": "true"})

# Extract and print the text from each span
for span in spans:
    print(span.text)
# Out:
# 720
# 648
# 269
# 120
# 100
# 200
# 190
# 249
# 167
# 158
# 350
# 200
# 249
# 249
# 169
# 160
# 720
# 648
# 190
# 380
# 298
# 277
# 380
# 400
# 199
# 200
# 169
# 160
# 379
# 249
# 277
# 263
# 235
# 223
# 400
# 349
# 320
# 220
# 165
# 400
# 598
# 199
# 189
# 209
# 490
# 416
# 685
# 380
# 459
# 280
# 250
# 300
# 285
# 680
# 277
# 263
# 1.163
# 199
# 163
# 243
# 230
# 463
# 227
# 215
# 435
# 277
# 263
# 598
# 399
# 236
# 280
# 236

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://listado.mercadolibre.com.mx/plush-toy-fisher-price-smart-puppy-learn-for-6-36-months#D[A:Plush%20Toy%20Fisher-Price%20Smart%20Puppy%20Learn%20for%206-36%20Months]"
page = urlopen(url)
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Find all items
items = soup.find_all("div", class_="ui-search-result__content-wrapper")

# Extract and print the price, name, and URL for each item
for item in items:
    # Extract the name
    name_tag = item.find("h2", class_="ui-search-item__title")
    if name_tag:
        name = name_tag.text
    else:
        name = "N/A"

    # Extract the price
    price_tag = item.find("span", class_="andes-money-amount__fraction", attrs={"aria-hidden": "true"})
    if price_tag:
        price = price_tag.text
    else:
        price = "N/A"

    # Extract the URL
    url_tag = item.find("a", class_="ui-search-item__group__element ui-search-link__title-card ui-search-link")
    if url_tag and 'href' in url_tag.attrs:
        item_url = url_tag['href']
    else:
        item_url = "N/A"

    print(f"Name: {name}")
    print(f"Price: {price}")
    print(f"URL: {item_url}")
    print("-------------")
# Out:
# Name: Fisher-price Laugh Learn Baby Learning Toy, Puppys Remote Fi
# Price: 947
# URL: https://articulo.mercadolibre.com.mx/MLM-2610675850-fisher-price-laugh-learn-baby-learning-toy-puppys-remote-fi-_JM#position=1&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Laugh & Learn Baby Learning Toy Puppys Activity
# Price: 999
# URL: https://articulo.mercadolibre.com.mx/MLM-1897747151-fisher-price-laugh-learn-baby-learning-toy-puppys-activity-_JM#position=2&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Laugh Learn Baby Learning Toy Puppys Music Play
# Price: 1,004
# URL: https://articulo.mercadolibre.com.mx/MLM-2610612910-fisher-price-laugh-learn-baby-learning-toy-puppys-music-play-_JM#position=3&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Laugh & Learn Baby & Toddler Toy Puppy's Game A
# Price: 1,107
# URL: https://articulo.mercadolibre.com.mx/MLM-2727925090-fisher-price-laugh-learn-baby-toddler-toy-puppys-game-a-_JM#position=4&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Baby Plush Toy Calming Vibes Puppy Soother Máqu
# Price: 999
# URL: https://articulo.mercadolibre.com.mx/MLM-2835012174-fisher-price-baby-plush-toy-calming-vibes-puppy-soother-maqu-_JM#position=5&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Laugh & Learn Smart Stages Puppy Brown
# Price: 990
# URL: https://articulo.mercadolibre.com.mx/MLM-1657159063-fisher-price-laugh-learn-smart-stages-puppy-brown-_JM#position=6&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Laugh - Learn Smart Stages Puppy
# Price: 2,199
# URL: https://articulo.mercadolibre.com.mx/MLM-1882681598-fisher-price-laugh-learn-smart-stages-puppy-_JM#position=7&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Fisher-price Ríe & Learn Smart Stages Cachorro
# Price: 732
# URL: https://articulo.mercadolibre.com.mx/MLM-1880790517-fisher-price-rie-learn-smart-stages-cachorro-_JM#position=8&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
# Name: Smart Stages, Puppy Irma Learn And Play, Fisher Price, Matte
# Price: 1,674
# URL: https://articulo.mercadolibre.com.mx/MLM-1452368996-smart-stages-puppy-irma-learn-and-play-fisher-price-matte-_JM#position=9&search_layout=grid&type=item&tracking_id=7f83f2ad-40f5-4e29-a02f-d6769b92259a
# -------------
